# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# **Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# **Read Salaries.csv as a dataframe called sal.**

# %%
import pandas as pd
sal = pd.read_csv('Salaries.csv')
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_20156\185440898.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal = pd.read_csv('Salaries.csv')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
import pandas as pd
header = sal.head()

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
import pandas as pd
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
import pandas as pd
sal.info()
# Or specifically for that column:
print(sal['BasePay'].dtype)
# Converts BasePay to numeric, turning strings into NaN
sal['BasePay'] = pd.to_numeric(sal['BasePay'], errors='coerce')
# Now run the mean
sal['BasePay'].mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB
# object
# np.float64(66325.44884048769)

# %% [markdown]
# **What is the highest amount of OvertimePay in the dataset ?**

# %%
import pandas as pd
sal.info()
# Or specifically for that column:
print(sal['OvertimePay'].dtype)
# Converts OvertimePay to numeric, turning strings into NaN
sal['OvertimePay'] = pd.to_numeric(sal['OvertimePay'], errors='coerce')
# Now run the max
sal['OvertimePay'].max()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 14.7+ MB
# float64
# np.float64(245131.88)

# %% [markdown]
# **What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).**

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)?**

# %%
import pandas as pd
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits'].iloc[0]
#
# NameError: name 'sal' is not defined

# %% [markdown]
# **What is the name of highest paid person (including benefits)?**

# %%
import pandas as pd
sal.loc[sal['TotalPayBenefits'].idxmax()]['EmployeeName']
# Out:
# ['NATHANIEL FORD']

# %% [markdown]
# **What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
import pandas as pd
sal.loc[sal['TotalPayBenefits'].idxmin()]
# Out:
# ['Joe Lopez']

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year? (2011-2014) ?**

# %%
import pandas as pd
sal.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# **How many unique job titles are there?**

# %%
import pandas as pd
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# **What are the top 5 most common jobs?**

# %%
import pandas as pd
sal['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# **How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)**

# %%
import pandas as pd
sum(sal[sal['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# **How many people have the word Chief in their job title? (This is pretty tricky)**

# %%
import pandas as pd
def chief_string(title):
    if 'chief' in title.lower().split():
        return True
    else:
        return False
sum(sal['JobTitle'].apply(lambda x: chief_string(x)))

# %% [markdown]
# **Is there a correlation between length of the Job Title string and Salary?**

# %%
import pandas as pd
sal['title_len'] = sal['JobTitle'].apply(len)
sal[['title_len', 'TotalPayBenefits']].corr()

# %% [markdown]
# # Great Job!
